# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0  0.772578 -1.732804  1.758329  0.745801 -0.853850
# 1  0.901318  1.753032 -0.814731 -1.387968 -0.082515
# 2  1.337998  0.415518 -0.369537  0.555362 -0.197219
# 3 -0.562736 -0.141746  0.311968 -1.952021 -0.014059
# 4 -1.261278 -0.637555  1.527964  0.294503  0.025057
# 5  1.706543 -0.698278  0.463428 -0.075937 -0.512580
# 6  0.295796  0.100710  0.065892 -0.540286  0.396840
# 7 -1.641299  1.427954  2.751473 -0.092009  1.278811
# 8 -1.022643 -1.764975  0.123211 -0.278957  1.230903
# 9  2.039855  0.760607  0.266920 -0.410015  1.019701

# %% [markdown]
# ## CSV
#
# ### Guardar en un archivo CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0  0.053605 -1.137298  1.004489 -0.118828 -1.362736
# 1 -0.457394  1.347877 -0.443760 -0.512531 -1.020369
# 2 -0.398394 -0.495549 -0.031356 -0.061928  1.119282
# 3  0.894206 -0.770804 -0.033084 -0.645493  0.740276
# 4  0.067762 -0.688263  0.195301 -0.501617 -0.848304
# 5 -0.350835  0.135339  0.944632 -1.019544 -0.779629
# 6  1.134961  0.640051  0.421892  0.208544  0.092138
# 7  0.220720 -0.543537  0.952338  1.061907 -0.318605
# 8  0.281994 -0.833309  1.991691 -0.080786 -0.399603
# 9 -1.617234 -1.231738 -1.247005 -0.555105  0.934667

# %% [markdown]
# ## JSON
#
# ### Guardar en JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0  0.053605 -1.137298  1.004489 -0.118828 -1.362736
# 1 -0.457394  1.347877 -0.443760 -0.512531 -1.020369
# 2 -0.398394 -0.495549 -0.031356 -0.061928  1.119282
# 3  0.894206 -0.770804 -0.033084 -0.645493  0.740276
# 4  0.067762 -0.688263  0.195301 -0.501617 -0.848304
# 5 -0.350835  0.135339  0.944632 -1.019544 -0.779629
# 6  1.134961  0.640051  0.421892  0.208544  0.092138
# 7  0.220720 -0.543537  0.952338  1.061907 -0.318605
# 8  0.281994 -0.833309  1.991691 -0.080786 -0.399603
# 9 -1.617234 -1.231738 -1.247005 -0.555105  0.934667

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\irving\appdata\roaming\python\python311\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\irving\appdata\roaming\python\python311\site-packages (from openpyxl) (1.1.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='nombreHojaCalculo', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='nombreHojaCalculo')

df
# Out:
#           A         B         C         D         E
# 0  0.972153 -0.302457 -2.527142  0.728854  0.726119
# 1  0.900955  1.151576  0.975418 -1.451026  0.119699
# 2 -0.353283  0.493331  0.270446 -0.270130 -1.010382
# 3 -0.222773  0.388908 -1.645478 -1.775483  1.761060
# 4  1.648038 -1.466584  0.126211 -1.518091  0.577144
# 5 -0.128429  0.296862 -0.236618 -0.535366 -1.885108
# 6 -0.501596 -1.050634 -1.147112  1.462538  1.164727
# 7 -0.198838 -1.389498  0.994139 -0.102514 -0.085598
# 8 -0.676380  0.470701 -0.790729 -1.397439  0.069483
# 9 -1.846902 -0.908061  0.888508 -0.202535  0.931184

# %% [markdown]
# ## HTML
#
# Podemos extraer información directamente desde tablas de páginas web a partir de la URL.
#
# Esto se consigue haciendo web scrapping con los módulos `lxml` y `BeautifulSoup4`, por lo que necesitamos instalarlos:
#
#     pip install lxml BeautifulSoup4

# %%
# !pip install lxml BeautifulSoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in c:\users\irving\appdata\roaming\python\python311\site-packages (4.9.2)
# Requirement already satisfied: BeautifulSoup4 in c:\users\irving\appdata\roaming\python\python311\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\irving\appdata\roaming\python\python311\site-packages (from BeautifulSoup4) (2.3.2.post1)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Una vez instalado `lxml` y `BeautifulSoup4` reiniciamos el kernel (botón girando al lado de stop) y ya estaremos listos:

# %%
# Realizamos un scrapping de una tabla de la wikipedia. Recupera TODAS las TABLAS de la pagina web
df = pd.read_html('https://web.archive.org/web/20220717170349/https://en.wikipedia.org/wiki/List_of_countries_by_past_fertility_rate')

# %% [markdown]
# Si se encuentra más de una tabla (como en el caso del ejemplo), podemos hacer referencia al primero a través del índice:

# %%
df[2]
# Out:
#     Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970
# 0                   Afghanistan       7.45       7.45       7.45       7.45  \
# 1                       Albania       6.23       6.55       6.23       5.26
# 2                       Algeria       7.28       7.38       7.65       7.65
# 3                        Angola       7.30       7.35       7.60       7.60
# 4           Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                          ...        ...        ...        ...        ...
# 197           Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                       Yemen       7.35       7.40       7.60       7.80
# 199                      Zambia       6.70       6.95       7.25       7.30
# 200                    Zimbabwe       6.80       7.00       7.30       7.40
# 201                       World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000
# 0         7.45       7.45       7.45       7.45       7.48       7.65  \
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Podemos hacer un poco de limpieza y dejar los datos presentables:

# %%
# Guardamos el dataframe
fertility_rate = df[2]

fertility_rate.head()
# Out:
#   Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970
# 0                 Afghanistan       7.45       7.45       7.45       7.45  \
# 1                     Albania       6.23       6.55       6.23       5.26
# 2                     Algeria       7.28       7.38       7.65       7.65
# 3                      Angola       7.30       7.35       7.60       7.60
# 4         Antigua and Barbuda       4.50       4.50       4.30       4.00
#
#    1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000
# 0       7.45       7.45       7.45       7.45       7.48       7.65  \
# 1       4.60       3.90       3.41       3.15       2.79       2.38
# 2       7.57       7.18       6.32       5.30       4.12       2.88
# 3       7.60       7.60       7.40       7.35       7.10       6.75
# 4       3.26       2.24       2.14       2.07       2.09       2.31
#
#    2000–2005  2005–2010  2010–2015
# 0       7.18       6.37       5.26
# 1       1.95       1.64       1.71
# 2       2.38       2.72       2.96
# 3       6.55       6.35       5.95
# 4       2.27       2.17       2.10

# %%
# Renombramos la primera columna para que sea más fácil consultarla
fertility_rate.rename(columns = {'Country/dependent territory':'Country'}, inplace=True)

fertility_rate
# Out:
#                  Country  1950–1955  1955–1960  1960–1965  1965–1970
# 0            Afghanistan       7.45       7.45       7.45       7.45  \
# 1                Albania       6.23       6.55       6.23       5.26
# 2                Algeria       7.28       7.38       7.65       7.65
# 3                 Angola       7.30       7.35       7.60       7.60
# 4    Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                   ...        ...        ...        ...        ...
# 197    Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                Yemen       7.35       7.40       7.60       7.80
# 199               Zambia       6.70       6.95       7.25       7.30
# 200             Zimbabwe       6.80       7.00       7.30       7.40
# 201                World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000
# 0         7.45       7.45       7.45       7.45       7.48       7.65  \
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Ahora podemos realizar consultas cómodamente:

# %%
# Índice de natalidad por país entre los años 2010-2015
fertility_rate[["Country", "2010–2015"]]
# Out:
#                  Country  2010–2015
# 0            Afghanistan       5.26
# 1                Albania       1.71
# 2                Algeria       2.96
# 3                 Angola       5.95
# 4    Antigua and Barbuda       2.10
# ..                   ...        ...
# 197    Western Sahara[7]       2.60
# 198                Yemen       4.40
# 199               Zambia       5.20
# 200             Zimbabwe       4.00
# 201                World       2.52
#
# [202 rows x 2 columns]

# %%
# Misma consulta aplicando el styler para esconder la primera columna
fertility_rate[["Country", "2010–2015"]].head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_13397">
#   <thead>
#     <tr>
#       <th id="T_13397_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_13397_level0_col1" class="col_heading level0 col1" >2010–2015</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_13397_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_13397_row0_col1" class="data row0 col1" >5.260000</td>
#     </tr>
#     <tr>
#       <td id="T_13397_row1_col0" class="data row1 col0" >Albania</td>
#       <td id="T_13397_row1_col1" class="data row1 col1" >1.710000</td>
#     </tr>
#     <tr>
#       <td id="T_13397_row2_col0" class="data row2 col0" >Algeria</td>
#       <td id="T_13397_row2_col1" class="data row2 col1" >2.960000</td>
#     </tr>
#     <tr>
#       <td id="T_13397_row3_col0" class="data row3 col0" >Angola</td>
#       <td id="T_13397_row3_col1" class="data row3 col1" >5.950000</td>
#     </tr>
#     <tr>
#       <td id="T_13397_row4_col0" class="data row4 col0" >Antigua and Barbuda</td>
#       <td id="T_13397_row4_col1" class="data row4 col1" >2.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más a menos (primeros resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6aa6e">
#   <thead>
#     <tr>
#       <th id="T_6aa6e_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_6aa6e_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6aa6e_row0_col0" class="data row0 col0" >Yemen</td>
#       <td id="T_6aa6e_row0_col1" class="data row0 col1" >8.800000</td>
#     </tr>
#     <tr>
#       <td id="T_6aa6e_row1_col0" class="data row1 col0" >Oman</td>
#       <td id="T_6aa6e_row1_col1" class="data row1 col1" >7.850000</td>
#     </tr>
#     <tr>
#       <td id="T_6aa6e_row2_col0" class="data row2 col0" >Rwanda</td>
#       <td id="T_6aa6e_row2_col1" class="data row2 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_6aa6e_row3_col0" class="data row3 col0" >Niger</td>
#       <td id="T_6aa6e_row3_col1" class="data row3 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_6aa6e_row4_col0" class="data row4 col0" >Burundi</td>
#       <td id="T_6aa6e_row4_col1" class="data row4 col1" >7.550000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más o menos (últimos resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).tail().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0f31">
#   <thead>
#     <tr>
#       <th id="T_a0f31_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_a0f31_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0f31_row0_col0" class="data row0 col0" >Austria</td>
#       <td id="T_a0f31_row0_col1" class="data row0 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_a0f31_row1_col0" class="data row1 col0" >Guernsey and Jersey (UK)</td>
#       <td id="T_a0f31_row1_col1" class="data row1 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_a0f31_row2_col0" class="data row2 col0" >Germany</td>
#       <td id="T_a0f31_row2_col1" class="data row2 col1" >1.430000</td>
#     </tr>
#     <tr>
#       <td id="T_a0f31_row3_col0" class="data row3 col0" >Hong Kong (China)</td>
#       <td id="T_a0f31_row3_col1" class="data row3 col1" >1.360000</td>
#     </tr>
#     <tr>
#       <td id="T_a0f31_row4_col0" class="data row4 col0" >Italy</td>
#       <td id="T_a0f31_row4_col1" class="data row4 col1" >1.350000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Vamos a transformar todas las columnas desde la segunda hasta la última a valores númericos
fertility_rate = fertility_rate[1:][:].apply(pd.to_numeric, errors='coerce')

# %%
# Ahora podemos consultar la media del índice de natalidad para cada año
fertility_rate.mean()[1:]
# Out:
# 1950–1955    5.447612
# 1955–1960    5.505622
# 1960–1965    5.501791
# 1965–1970    5.281940
# 1970–1975    4.991542
# 1975–1980    4.651343
# 1980–1985    4.393383
# 1985–1990    4.101592
# 1990–1995    3.738209
# 1995–2000    3.388955
# 2000–2005    3.120498
# 2005–2010    2.973234
# 2010–2015    2.837910
# dtype: float64

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 12,5 #Tamaño deseado del gráfico

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# <Axes: xlabel='Períodos', ylabel='Media de natalidad mundial'>

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
